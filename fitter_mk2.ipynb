# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
#import tools_mk3 as fitter
from tools_mk4 import Fitter
from scipy.optimize import curve_fit

# %% [markdown]
# ## Guess

# %%
fitter = Fitter(spec_path="./spectra_elias29.json", wn_min=600, wn_max=4000)
# Out:
# /home/lars/AarhusUniversity/IceFitter/tools_mk4.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['tau'] = [-np.log(fo/fc) for fo, fc in zip(plot_df['Flux (Jy)'], interp_cont)]
# /home/lars/AarhusUniversity/IceFitter/tools_mk4.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df['error_tau'] = [sigf/f for f, sigf in zip(plot_df['Flux (Jy)'], plot_df['Sigma (Jy)'])]

# %%
fitter.plot_spectra(save_model=False)

# %% [markdown]
# ## Fit

# %%
fitter.do_fit()

# %%
fitter.plot_spectra(save_model=False)

# %%
# remember to think about the contribution of the cloud AND the disk AND the protostar
